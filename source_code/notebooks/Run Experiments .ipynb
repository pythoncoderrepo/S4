# %%
from itertools import product 
from datetime import datetime
from source_code.core.hypothesis_evaluation.test_handler import run_tests_for

# %% [markdown]
# ## Retail

# %%
###########

cases_list = []

datasets = ["Retail"]
error_correction_test = "fdr_by"
    
test_types =["mean"]
test_args = ['Two-Samples'] 

approaches = [1,2]
alphas = [0.05,0.01]

pivot_types = ["Promotion" ]
pivot_args = [[datetime(2018,12,17),datetime(2019,2,28)]]
segmentation_types  = ["Demographics"]
segmentation_args = [["location","gender"]]

segmentation_types  = ["Window"]
# segmentation_args = [500,1000]
segmentation_args = [2000, 1000, 500]
cases = product(datasets, pivot_types, pivot_args, segmentation_types, segmentation_args, test_types, test_args, approaches,alphas)
cases_list.append(cases)


pivot_types = [None ]
pivot_args = [[datetime(2018,12,17),datetime(2019,2,28)]]
pivot_args = [[1],[10],[500]]
segmentation_types  = ["Window"]
segmentation_types  = ["Demographics"]
segmentation_args = [500,1000]
segmentation_args = ["location"]
cases = product(datasets, pivot_types, pivot_args, segmentation_types, segmentation_args, test_types, test_args, approaches,alphas)
cases_list.append(cases)

segmentation_types  = ["Demographics"]
segmentation_args = [["location","gender"]]
# segmentation_args = [5000,2000,1000]
cases = product(datasets, pivot_types, pivot_args, segmentation_types, segmentation_args, test_types, test_args, approaches,alphas)
cases_list.append(cases)



segmentation_types  = ["Demographics"]
segmentation_args= ["gender","location",["gender","location"]]
segmentation_args= ["location"]
cases = product(datasets, pivot_types, pivot_args, segmentation_types, segmentation_args, test_types, test_args, approaches,alphas)
cases_list.append(cases)



pivot_types = ["Demographics" ]
pivot_args = ["gender"]
segmentation_types  = ["Window"]
segmentation_args= [500]
cases = product(datasets, pivot_types, pivot_args, segmentation_types, segmentation_args, test_types, test_args, approaches,alphas)
cases_list.append(cases)


segmentation_types  = ["Demographics"]
segmentation_args= ["gender",]
cases = product(datasets, pivot_types, pivot_args, segmentation_types, segmentation_args, test_types, test_args, approaches,alphas)
cases_list.append(cases)



for cases in cases_list:
    for dataset , pivot_type , pivot_arg , segmentation_type , segmentation_arg , test_type , test_arg , approach ,alpha in cases:
        exp_name = "_".join(str(i) for i in [dataset,error_correction_test,approach,alpha,pivot_type,pivot_arg,segmentation_type,segmentation_arg])
        a = run_tests_for(dataset,
                       pivot_type,
                       pivot_arg,
                       segmentation_type,
                       segmentation_arg,
                       test_type,
                       test_arg,
                       approach,
                       alpha)

# %% [markdown]
# ## Amazon

# %%
from itertools import product 
from datetime import datetime
cases_list = []



datasets = ["Amazon"]
error_correction_tests = ["fdr_by"]
error_correction_test = "fdr_by"

test_types =["mean"]
test_args = ['Two-Samples'] 

approaches = [1,2]
alphas = [0.05,0.01]
alphas = [0.05,0.01]


pivot_types = ["Promotion" ]
pivot_args = [[datetime(2016,11,20),datetime(2017,1,1)]]
segmentation_types  = ["Window"]
segmentation_args= [1000]
cases = product(datasets, pivot_types, pivot_args, segmentation_types, segmentation_args, test_types, test_args, approaches,alphas)
cases_list.append(cases)


    
    
for cases in cases_list:
    for dataset , pivot_type , pivot_arg , segmentation_type , segmentation_arg , test_type , test_arg , approach ,alpha in cases:
        run_tests_for(dataset,
                       pivot_type,
                       pivot_arg,
                       segmentation_type,
                       segmentation_arg,
                       test_type,
                       test_arg,
                       approach,
                       alpha)

# %% [markdown]
# ## Tafeng

# %%
from itertools import product 
from datetime import datetime
cases_list = []



datasets = ["Tafeng"]
error_correction_test = ["fdr_by"][0]

test_types =["mean"]
test_args = ['One-Sample'] 

approaches = [1,2]
alphas = [0.05]


pivot_types = ["Demographics" ]
pivot_args = ["age-range"]
segmentation_types  = ["Window"]
segmentation_args= ["10000","10000","3000","2000"]
segmentation_args= ["10000"]
cases = product(datasets, pivot_types, pivot_args, segmentation_types, segmentation_args, test_types, test_args, approaches,alphas)
cases_list.append(cases)


pivot_types = ["Promotion" ]
pivot_args = [[datetime(2001,1,24),datetime(2001,1,24)]]
segmentation_types  = ["Window"]
segmentation_args= ["500","10000","3000","2000"]
segmentation_args= ["1000"]
cases = product(datasets, pivot_types, pivot_args, segmentation_types, segmentation_args, test_types, test_args, approaches,alphas)
cases_list.append(cases)



pivot_types = [None]
pivot_args = [[150],[500]]
segmentation_types  = ["Demographics"]
segmentation_types  = ["Window"]
segmentation_args= ["300","400","350","450"]
segmentation_args= ["2W"]
cases = product(datasets, pivot_types, pivot_args, segmentation_types, segmentation_args, test_types, test_args, approaches,alphas)
cases_list.append(cases)



segmentation_types  = ["Demographics"]
segmentation_args= ["age","age-range"]
cases = product(datasets, pivot_types, pivot_args, segmentation_types, segmentation_args, test_types, test_args, approaches,alphas)
cases_list.append(cases)



for cases in cases_list:
    for dataset , pivot_type , pivot_arg , segmentation_type , segmentation_arg , test_type , test_arg , approach ,alpha in cases:
        exp_name = "_".join(str(i) for i in [dataset,error_correction_test,approach,alpha,pivot_type,pivot_arg,segmentation_type,segmentation_arg])
        result,exp_name,time_report = run_tests_for(dataset,
                       pivot_type,
                       pivot_arg,
                       segmentation_type,
                       segmentation_arg,
                       test_type,
                       test_arg,
                       approach,
                       alpha)

# %% [markdown]
# ## Sales

# %%
from itertools import product 
cases_list = []


datasets = ["Sales"]
error_correction_tests = ["fdr_by"]

test_types =["mean"]
test_args = ['Two-Samples'] 

approaches = [1]
alphas = [0.05,0.01]


pivot_types = ["Promotion" ]
pivot_args = [["is_holiday"]]
segmentation_types  = ["Window"]
segmentation_args= ["10000","3000","2000"]
cases = product(datasets, pivot_types, pivot_args, segmentation_types, segmentation_args, test_types, test_args, approaches,alphas)
cases_list.append(cases)



for cases in cases_list:
    for dataset , pivot_type , pivot_arg , segmentation_type , segmentation_arg , test_type , test_arg , approache ,alpha in cases:
        result,exp_name,time_report = run_tests_for(dataset,
                       pivot_type,
                       pivot_arg,
                       segmentation_type,
                       segmentation_arg,
                       test_type,
                       test_arg,
                       approach,
                       alpha)
